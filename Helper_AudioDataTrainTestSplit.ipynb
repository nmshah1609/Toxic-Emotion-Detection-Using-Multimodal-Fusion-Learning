# %% [markdown]
# # Split Audio Data into Train and Test
#
# Split audio data (audio files and mel-spectrograms) into training and testing subfolders.
# ___
# Abhay Jolly | ajolly@sfu.ca\
# Harry Preet Singh | hps1@sfu.ca\
# Karan Pathania | kpathani@sfu.ca\
# Neil Mukesh Shah | nmshah@sfu.ca
# ___
# CMPT 419, Spring 2022\
# Simon Fraser University

# %%
# Mount google drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
% pip install split-folders

# %%
import splitfolders

INPUT_DIR_AUDIO = '/content/drive/MyDrive/CMPT 419 Project/audio_dataset/audio_data'
OUTPUT_DIR_AUDIO = '/content/drive/MyDrive/CMPT 419 Project/audio_dataset/audio_data_split'

INPUT_DIR_MEL = '/content/drive/MyDrive/CMPT 419 Project/audio_dataset/spectrogram_mel'
OUTPUT_DIR_MEL = '/content/drive/MyDrive/CMPT 419 Project/audio_dataset/spectrogram_mel_split'

TRAIN_TEST_RATIO = (0.75, 0.25)

splitfolders.ratio(INPUT_DIR_AUDIO, output = OUTPUT_DIR_AUDIO, seed = 42, ratio = TRAIN_TEST_RATIO)
splitfolders.ratio(INPUT_DIR_MEL, output = OUTPUT_DIR_MEL, seed = 42, ratio = TRAIN_TEST_RATIO)
# Out:
# Copying files: 499 files [00:13, 37.90 files/s]
